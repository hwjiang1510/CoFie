# %%
import torch
import numpy as np
import open3d as o3d
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
file_path = 'data/SurfaceSamples/ShapeNetV2/02691156/d3b9114df1d8a3388e415c6cf89025f0.ply'

pcd = o3d.io.read_point_cloud(file_path)
pcd = np.asarray(pcd.points)

# %%
pcd.shape
# Out:
# (30000, 3)

# %%
def get_voxel_indices(points, voxel_resolution, volume_size_half):
    # Normalize points to [0, 1]
    normalized_points = (points[:, :3] + volume_size_half) / (2 * volume_size_half)
    # Convert to voxel indices
    voxel_indices = (normalized_points * voxel_resolution).floor().long()
    return voxel_indices

# %%
pcd[:10]
# Out:
# array([[-0.266687 ,  0.014661 ,  0.0714391],
#        [-0.097616 ,  0.059629 ,  0.0327963],
#        [ 0.129014 ,  0.0490736,  0.0467457],
#        [ 0.0137107, -0.0435493,  0.104879 ],
#        [-0.003545 ,  0.115527 ,  0.326341 ],
#        [-0.25705  ,  0.0389597, -0.0485951],
#        [-0.0259822,  0.0429778, -0.025618 ],
#        [-0.0517072,  0.050338 ,  0.099694 ],
#        [-0.0275918,  0.0404751, -0.163802 ],
#        [ 0.257034 ,  0.0455434,  0.0119498]])

# %%
normalization_param = np.load('data/NormalizationParameters/ShapeNetV2/02691156/d3b9114df1d8a3388e415c6cf89025f0.npz')

# %%
normalization_param.files
# Out:
# ['offset', 'scale']

# %%
normalization_param['offset']
# Out:
# array([ 8.001924e-06, -6.018100e-02, -1.986000e-02], dtype=float32)

# %%
normalization_param['scale']
# Out:
# array([2.367257], dtype=float32)

# %%
pcd[:,2].max()
# Out:
# 0.407095

# %%
sdf = np.load('data/SdfSamples/ShapeNetV2/02691156/1a6ad7a24bb89733f412783097373bdc.npz')
sdf = np.load('data/SdfSamples/ShapeNetV2/04256520/cd249bd432c4bc75b82cf928f6ed5338.npz')

# %%
sdf_pos = sdf['pos']
sdf_neg = sdf['neg']

# %%
sdf_pos[:,-1].max()
# Out:
# 1.1694136

# %%
sdf_pos.shape
# Out:
# (196511, 4)

# %%
sdf_neg.shape
# Out:
# (288854, 4)

# %%
sdf_pos[:,0].min()
# Out:
# -1.1342893

# %%
sdf_all = np.vstack((sdf_pos, sdf_neg))
sdf_all.shape
# Out:
# (485365, 4)

# %%
sdf_surface = sdf_all[np.abs(sdf_all[:,-1]) < 0.1]
sdf_surface.shape
# Out:
# (446055, 4)

# %%
voxel_indices = get_voxel_indices(torch.tensor(sdf_surface[:,:3]), voxel_resolution=32, volume_size_half=1.2)

# %%
voxel_indices.shape
# Out:
# torch.Size([446055, 3])

# %%
voxel_indices[:10]
# Out:
# tensor([[19, 15, 19],
#         [13, 12, 17],
#         [ 9, 15, 13],
#         [13, 16, 18],
#         [22, 12, 11],
#         [26, 13, 14],
#         [25, 14, 14],
#         [14, 13, 10],
#         [14, 16, 11],
#         [14, 15, 10]])

# %%
unique_voxels = torch.unique(voxel_indices, dim=0)

# %%
unique_voxels.shape
# Out:
# torch.Size([2582, 3])

# %%
unique_voxels
# Out:
# tensor([[ 3, 11, 10],
#         [ 3, 11, 11],
#         [ 3, 11, 21],
#         ...,
#         [28, 20, 19],
#         [28, 20, 20],
#         [28, 20, 21]])

# %%
def generate_grid_center_indices(voxel_resolution=32, volume_size_half=1.2):
    '''
    return voxel coordinate in shape [R^3,3], R is cube_size
    '''
    # Divide space into equally spaced subspaces and calculate center position of subspace
    voxel_centers = np.linspace(-volume_size_half, volume_size_half, voxel_resolution, endpoint=False)
    voxel_centers += volume_size_half / voxel_resolution
    # Create grid indices
    all_voxel_centers = np.vstack(np.meshgrid(voxel_centers, voxel_centers, voxel_centers)).reshape(3, -1).T
    all_voxel_centers = torch.tensor(all_voxel_centers).reshape(voxel_resolution, voxel_resolution, voxel_resolution, 3).permute(1,0,2,3)
    return all_voxel_centers

# %%
voxel_coordinate = generate_grid_center_indices()

# %%
voxel_indices_clamp = voxel_indices.clamp(min=-0.1, max=31.1).long()

# %%
surface_voxel_coordinate = voxel_coordinate[voxel_indices[:,0].long(), voxel_indices[:,1].long(), voxel_indices[:,2].long(), :]#.clamp(min=0, max=31)

# %%
(surface_voxel_coordinate - sdf_surface[:,:3]).max()
# Out:
# tensor(0.0375, dtype=torch.float64)

# %%
(surface_voxel_coordinate[333] - sdf_surface[333][:3]).mean()
# Out:
# tensor(0.0111, dtype=torch.float64)

# %%
torch.argmin(surface_voxel_coordinate - sdf_surface[:,:3], dim=0)
# Out:
# tensor([429910, 321594, 340734])

# %%
tmp = get_voxel_indices(voxel_coordinate.reshape(-1,3), voxel_resolution=32, volume_size_half=1.2)

# %%
voxel_coordinate_back = voxel_coordinate[tmp[:,0].long(), tmp[:,1].long(), tmp[:,2].long(), :]

# %%
str(unique_voxels[0].numpy().tolist()).replace('[', '').replace(']','')
# Out:
# '[3, 11, 10]'

# %%
from scipy.spatial import cKDTree
sdf_tree = cKDTree(sdf_all[:,:3])
voxel_size = (1.2 * 2) / 32
sdf_grid_radius = 1.5 * voxel_size
results = {}
voxel_coordinates_unique = voxel_coordinate[unique_voxels[:,0].long(), unique_voxels[:,1].long(), unique_voxels[:,2].long(), :]
for cur_voxel_idx, cur_voxel_coordinate in zip(unique_voxels, voxel_coordinates_unique):
    near_sample_indices = sdf_tree.query_ball_point(x=cur_voxel_coordinate.numpy(), r=sdf_grid_radius, p=np.inf)
    key_name =  str(cur_voxel_idx.numpy().tolist()).replace('[', '').replace(']','')
    results[key_name] = near_sample_indices

# %%
type(near_sample_indices)
# Out:
# list

# %%
results_len = [len(v) for v in results.values()]

# %%
max(results_len), min(results_len), sum(results_len) / len(results_len)
# Out:
# (12890, 208, 4654.782726568552)

# %%
len(results.keys())
# Out:
# 2582

# %%
len(results['3, 11, 10'])
# Out:
# 321

# %%
num_pts = 0
for k in results.keys():
    num_pts += len(results[k])

# %%
key_name
# Out:
# '28, 20, 21'

# %%
a = [int(it.replace(' ', '')) for it in key_name.split(',')]

# %%
a
# Out:
# [28, 20, 21]

# %%
import json
f_name = 'data/SdfSamplesToVoxelIndices/ShapeNetV2/02691156/1021a0914a7207aff927ed529ad90a11_vol-1.2_res-32_expand-1.5.json'
with open(f_name) as f:
    file = json.load(f)

# %%
file.keys()
# Out:
# dict_keys(['1, 13, 15', '1, 14, 15', '2, 12, 15', '2, 13, 14', '2, 13, 15', '2, 13, 16', '2, 14, 13', '2, 14, 14', '2, 14, 15', '2, 14, 16', '2, 14, 17', '2, 15, 14', '2, 15, 15', '2, 15, 16', '3, 12, 14', '3, 12, 15', '3, 12, 16', '3, 13, 13', '3, 13, 14', '3, 13, 15', '3, 13, 16', '3, 14, 13', '3, 14, 14', '3, 14, 15', '3, 14, 16', '3, 14, 17', '3, 15, 14', '3, 15, 15', '3, 15, 16', '4, 12, 14', '4, 12, 15', '4, 12, 16', '4, 13, 13', '4, 13, 14', '4, 13, 15', '4, 13, 16', '4, 14, 13', '4, 14, 14', '4, 14, 15', '4, 14, 16', '4, 14, 17', '4, 15, 14', '4, 15, 15', '4, 15, 16', '5, 12, 14', '5, 12, 15', '5, 12, 16', '5, 13, 13', '5, 13, 14', '5, 13, 15', '5, 13, 16', '5, 14, 13', '5, 14, 14', '5, 14, 15', '5, 14, 16', '5, 14, 17', '5, 15, 14', '5, 15, 15', '5, 15, 16', '6, 12, 14', '6, 12, 15', '6, 12, 16', '6, 13, 13', '6, 13, 14', '6, 13, 15', '6, 13, 16', '6, 13, 17', '6, 14, 13', '6, 14, 14', '6, 14, 15', '6, 14, 16', '6, 14, 17', '6, 15, 13', '6, 15, 14', '6, 15, 15', '6, 15, 16', '7, 12, 14', '7, 12, 15', '7, 12, 16', '7, 13, 13', '7, 13, 14', '7, 13, 15', '7, 13, 16', '7, 13, 17', '7, 14, 13', '7, 14, 14', '7, 14, 15', '7, 14, 16', '7, 14, 17', '7, 15, 13', '7, 15, 14', '7, 15, 15', '7, 15, 16', '7, 15, 17', '8, 12, 13', '8, 12, 14', '8, 12, 15', '8, 12, 16', '8, 12, 17', '8, 13, 13', '8, 13, 14', '8, 13, 15', '8, 13, 16', '8, 13, 17', '8, 13, 18', '8, 14, 13', '8, 14, 14', '8, 14, 15', '8, 14, 16', '8, 14, 17', '8, 15, 13', '8, 15, 14', '8, 15, 15', '8, 15, 16', '8, 15, 17', '9, 12, 13', '9, 12, 14', '9, 12, 15', '9, 12, 16', '9, 12, 17', '9, 13, 13', '9, 13, 14', '9, 13, 15', '9, 13, 16', '9, 13, 17', '9, 13, 18', '9, 14, 13', '9, 14, 14', '9, 14, 15', '9, 14, 16', '9, 14, 17', '9, 15, 13', '9, 15, 14', '9, 15, 15', '9, 15, 16', '9, 15, 17', '9, 16, 24', '9, 16, 25', '10, 12, 13', '10, 12, 14', '10, 12, 15', '10, 12, 16', '10, 12, 17', '10, 13, 13', '10, 13, 14', '10, 13, 15', '10, 13, 16', '10, 13, 17', '10, 13, 18', '10, 14, 13', '10, 14, 14', '10, 14, 15', '10, 14, 16', '10, 14, 17', '10, 15, 13', '10, 15, 14', '10, 15, 15', '10, 15, 16', '10, 15, 17', '10, 15, 24', '10, 15, 25', '10, 16, 23', '10, 16, 24', '10, 16, 25', '10, 17, 23', '10, 17, 24', '10, 17, 25', '10, 17, 26', '10, 18, 24', '10, 18, 25', '11, 11, 15', '11, 11, 16', '11, 12, 13', '11, 12, 14', '11, 12, 15', '11, 12, 16', '11, 12, 17', '11, 13, 13', '11, 13, 14', '11, 13, 15', '11, 13, 16', '11, 13, 17', '11, 13, 18', '11, 14, 12', '11, 14, 13', '11, 14, 14', '11, 14, 15', '11, 14, 16', '11, 14, 17', '11, 14, 18', '11, 14, 19', '11, 14, 20', '11, 15, 14', '11, 15, 15', '11, 15, 16', '11, 15, 17', '11, 15, 18', '11, 15, 19', '11, 15, 20', '11, 15, 24', '11, 15, 25', '11, 16, 22', '11, 16, 23', '11, 16, 24', '11, 16, 25', '11, 16, 26', '11, 17, 24', '11, 17, 25', '11, 18, 24', '11, 18, 25', '12, 10, 16', '12, 11, 14', '12, 11, 15', '12, 11, 16', '12, 11, 17', '12, 12, 13', '12, 12, 14', '12, 12, 15', '12, 12, 16', '12, 12, 17', '12, 13, 12', '12, 13, 13', '12, 13, 14', '12, 13, 15', '12, 13, 16', '12, 13, 17', '12, 13, 18', '12, 13, 19', '12, 13, 20', '12, 14, 12', '12, 14, 13', '12, 14, 14', '12, 14, 15', '12, 14, 16', '12, 14, 17', '12, 14, 18', '12, 14, 19', '12, 14, 20', '12, 14, 21', '12, 15, 13', '12, 15, 14', '12, 15, 15', '12, 15, 16', '12, 15, 17', '12, 15, 18', '12, 15, 19', '12, 15, 20', '12, 15, 21', '12, 15, 24', '12, 15, 25', '12, 16, 16', '12, 16, 17', '12, 16, 18', '12, 16, 19', '12, 16, 20', '12, 16, 21', '12, 16, 23', '12, 16, 24', '12, 16, 25', '12, 16, 26', '12, 17, 23', '12, 17, 24', '12, 17, 25', '12, 18, 24', '12, 18, 25', '13, 11, 14', '13, 11, 15', '13, 11, 16', '13, 11, 17', '13, 12, 6', '13, 12, 7', '13, 12, 8', '13, 12, 9', '13, 12, 10', '13, 12, 11', '13, 12, 12', '13, 12, 13', '13, 12, 14', '13, 12, 15', '13, 12, 16', '13, 12, 17', '13, 12, 18', '13, 12, 19', '13, 13, 5', '13, 13, 6', '13, 13, 7', '13, 13, 8', '13, 13, 9', '13, 13, 10', '13, 13, 11', '13, 13, 12', '13, 13, 13', '13, 13, 14', '13, 13, 15', '13, 13, 16', '13, 1 ...

# %%
len(file['1, 13, 15'])
# Out:
# 269

# %%
file['1, 13, 15']
# Out:
# [35122,
#  203749,
#  252981,
#  47663,
#  206455,
#  297889,
#  24526,
#  21064,
#  45003,
#  330935,
#  45626,
#  200851,
#  267149,
#  14248,
#  81836,
#  7911,
#  99943,
#  20157,
#  209710,
#  111920,
#  272601,
#  160160,
#  227950,
#  312138,
#  214804,
#  112333,
#  266421,
#  272372,
#  70227,
#  66031,
#  299455,
#  188233,
#  217252,
#  81917,
#  250090,
#  149250,
#  188248,
#  81906,
#  115372,
#  220514,
#  186618,
#  63126,
#  14804,
#  284552,
#  106623,
#  124442,
#  172347,
#  163171,
#  200572,
#  191836,
#  288363,
#  36303,
#  236729,
#  206135,
#  213898,
#  206019,
#  132650,
#  116207,
#  51073,
#  64675,
#  33723,
#  85997,
#  174334,
#  209822,
#  128368,
#  258844,
#  220525,
#  202174,
#  138654,
#  16387,
#  103799,
#  254624,
#  294415,
#  203900,
#  274432,
#  123281,
#  199342,
#  48258,
#  32720,
#  314,
#  248746,
#  58165,
#  227295,
#  113042,
#  160151,
#  178995,
#  206716,
#  143531,
#  274966,
#  34621,
#  224933,
#  186283,
#  47162,
#  79791,
#  122617,
#  15005,
#  224123,
#  71495,
#  189005,
#  273325,
#  208016,
#  181940,
#  299297,
#  62581,
#  137176,
#  90786,
#  155777,
#  15030,
#  253948,
#  8464,
#  172134,
#  256069,
#  112702,
#  83445,
#  21939,
#  160200,
#  310281,
#  83532,
#  255637,
#  219996,
#  258950,
#  121659,
#  32268,
#  81606,
#  199771,
#  180454,
#  112361,
#  42470,
#  20879,
#  219633,
#  46452,
#  261630,
#  106825,
#  229201,
#  252350,
#  96352,
#  173163,
#  55438,
#  310685,
#  294416,
#  178527,
#  10371,
#  82362,
#  196369,
#  234988,
#  296601,
#  49637,
#  290941,
#  142928,
#  67383,
#  63164,
#  45530,
#  2783,
#  58111,
#  2973,
#  183270,
#  265483,
#  135752,
#  72245,
#  64897,
#  206418,
#  302004,
#  139597,
#  289649,
#  169997,
#  209711,
#  232677,
#  282626,
#  190704,
#  199955,
#  260627,
#  138861,
#  74642,
#  272771,
#  21136,
#  111731,
#  237397,
#  208453,
#  71834,
#  224124,
#  297249,
#  93280,
#  16388,
#  177347,
#  224360,
#  302726,
#  252594,
#  49436,
#  235822,
#  212128,
#  195429,
#  265835,
#  256253,
#  54325,
#  191280,
#  159510,
#  197779,
#  175754,
#  36163,
#  135960,
#  167696,
#  84005,
#  187612,
#  252723,
#  295077,
#  278557,
#  165385,
#  254124,
#  71063,
#  104752,
#  55100,
#  47163,
#  39407,
#  181353,
#  111732,
#  232030,
#  223075,
#  2974,
#  116299,
#  217124,
#  45399,
#  58166,
#  91676,
#  146310,
#  181352,
#  159226,
#  2724,
#  208017,
#  57024,
#  87694,
#  22536,
#  266085,
#  167599,
#  289643,
#  170027,
#  35990,
#  42120,
#  290197,
#  170061,
#  215306,
#  161007,
#  8611,
#  87030,
#  30746,
#  76739,
#  110478,
#  100072,
#  174571,
#  125647,
#  58637,
#  272656,
#  71843,
#  238603,
#  195835,
#  313868,
#  297407,
#  232428,
#  79275,
#  248003,
#  287609,
#  102404,
#  241689,
#  94825,
#  61049,
#  299074,
#  313493,
#  282303,
#  211997,
#  283655]

# %%
voxel_coordinate.shape
# Out:
# torch.Size([32, 32, 32, 3])

# %%
voxel_coordinate = generate_grid_center_indices()
a = torch.tensor([[0,0,0], [31,31,31], [28,20,21], [10,22,23]]).long()
i, j, k = a[:,0], a[:,1], a[:,2]
voxel_coordinate[i,j,k]
# Out:
# tensor([[-1.1625, -1.1625, -1.1625],
#         [ 1.1625,  1.1625,  1.1625],
#         [ 0.9375,  0.3375,  0.4125],
#         [-0.4125,  0.4875,  0.5625]], dtype=torch.float64)

# %%
a = torch.ones(10,4)
b = a[a[:,-1]<0]
len(b)
# Out:
# 0

# %%
import torch
codes = torch.rand(100,10)
index = torch.tensor([1, 10, 24, 2, 44, 26, 23]).long()
codes[index].shape
# Out:
# torch.Size([7, 10])

# %%
import numpy as np
import random
a = np.arange(10)
random.choices(a, k=5)
# Out:
# [8, 8, 1, 4, 6]
